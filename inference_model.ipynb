# %%
# %run model_training.ipynb
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x1122f01a0>
# Epoch 0 loss 0.7074
# Epoch 1 loss 0.6907
# Epoch 2 loss 0.6868
# Epoch 3 loss 0.6842
# Epoch 4 loss 0.6812
# Epoch 5 loss 0.6777
# Epoch 6 loss 0.6764
# Epoch 7 loss 0.6767
# Epoch 8 loss 0.6763
# Epoch 9 loss 0.6741
# Epoch 10 loss 0.6735
# Epoch 11 loss 0.6763
# Epoch 12 loss 0.6759
# Epoch 13 loss 0.6732
# Epoch 14 loss 0.6736
# Epoch 15 loss 0.6693
# Epoch 16 loss 0.6712
# Epoch 17 loss 0.6690
# Epoch 18 loss 0.6697
# Epoch 19 loss 0.6708
# Epoch 0 loss 0.7013
# Epoch 1 loss 0.6950
# Epoch 2 loss 0.6927
# Epoch 3 loss 0.6900
# Epoch 4 loss 0.6901
# Epoch 5 loss 0.6879
# Epoch 6 loss 0.6863
# Epoch 7 loss 0.6849
# Epoch 8 loss 0.6856
# Epoch 9 loss 0.6849
# Epoch 10 loss 0.6831
# Epoch 11 loss 0.6830
# Epoch 12 loss 0.6830
# Epoch 13 loss 0.6826
# Epoch 14 loss 0.6827
# Epoch 15 loss 0.6812
# Epoch 16 loss 0.6810
# Epoch 17 loss 0.6800
# Epoch 18 loss 0.6808
# Epoch 19 loss 0.6816

# %%
# Save model weights only for inference
torch.save(model.state_dict(), "models/model_weights.pt")
# Load for inference
model = SimpleNet()
state = torch.load("models/model_weights.pt", map_location="cpu")
model.load_state_dict(state)
model.eval()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Save model weights only for inference
# ----> 2 torch.save(model.state_dict(), "models/model_weights.pt")
#       3 # Load for inference
#       4 model = SimpleNet()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/serialization.py:966, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     963     f = os.fspath(f)
#     965 if _use_new_zipfile_serialization:
# --> 966     with _open_zipfile_writer(f) as opened_zipfile:
#     967         _save(
#     968             obj,
#     969             opened_zipfile,
#    (...)    972             _disable_byteorder_record,
#     973         )
#     974         return
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/serialization.py:828, in _open_zipfile_writer(name_or_buffer)
#     826 else:
#     827     container = _open_zipfile_writer_buffer
# --> 828 return container(name_or_buffer)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/serialization.py:792, in _open_zipfile_writer_file.__init__(self, name)
#     785     super().__init__(
#     786         torch._C.PyTorchFileWriter(
#     787             self.file_stream, get_crc32_options(), _get_storage_alignment()
#     788         )
#     789     )
#     790 else:
#     791     super().__init__(
# --> 792         torch._C.PyTorchFileWriter(
#     793             self.name, get_crc32_options(), _get_storage_alignment()
#     794         )
#     795     )
#
# RuntimeError: Parent directory models does not exist.
